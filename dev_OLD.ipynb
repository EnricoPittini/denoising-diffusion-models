# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torchvision.transforms import Compose, ToTensor, RandomResizedCrop
from torchvision.datasets import CIFAR10, MNIST, Flowers102
from torch.utils.data import DataLoader

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %load_ext autoreload
# %autoreload 2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device: %s' % device)
# Out:
# Device: cpu

# %% [markdown]
# # Create Dataset

# %%
from utils.diffusionDataset import DiffusionDataset

image_size = (128, 128)
batch_size = 16
#variance_schedule = np.ones(20)*0.0011
variance_schedule = np.linspace(0, 2e-2, 1000)       # from Ho et al. (2020)
#alpha_t = np.cos((t/T+s)/(1+s)*np.pi/2)**2             # from Nichol & Dhariwal (2021)

# %%
# TRAIN

dataset_flowers_train = Flowers102(root='datasets', split='train',
                  download=True)

dataset_train = DiffusionDataset(data=dataset_flowers_train,
                           variance_schedule=variance_schedule,
                           transform=Compose([ToTensor(),
                                            RandomResizedCrop(image_size)]))

data_loader_train = DataLoader(dataset_train,
                         batch_size=batch_size,
                         pin_memory=True,
                         shuffle=True)

# %%
# VAL

dataset_flowers_val = Flowers102(root='datasets', split='val',
                  download=True)

dataset_val = DiffusionDataset(data=dataset_flowers_val,
                           variance_schedule=variance_schedule,
                           transform=Compose([ToTensor(),
                                            RandomResizedCrop(image_size)]))

data_loader_val = DataLoader(dataset_val,
                         batch_size=batch_size,
                         pin_memory=True,
                         shuffle=True)

# %%
# TEST

dataset_flowers_test = Flowers102(root='datasets', split='test',
                  download=True)

dataset_test = DiffusionDataset(data=dataset_flowers_test,
                           variance_schedule=variance_schedule,
                           transform=Compose([ToTensor(),
                                            RandomResizedCrop(image_size)]))

data_loader_test = DataLoader(dataset_test,
                         batch_size=batch_size,
                         pin_memory=True,
                         shuffle=True)

# %% [markdown]
# ## Have a look at some elements in the dataset

# %%
from utils.reconstruction import reconstruct_image_from_noise

(im_n, t), noise = next(iter(data_loader_train))
im_n = im_n[0]
t = t.numpy()[0]
noise = noise[0]

im = reconstruct_image_from_noise(im_n, noise, t, variance_schedule)

print(f"Forward diffusion step at stage t = {t}.")

w, h, dpi = 1500, 500, 100
fig, ax = plt.subplots(ncols=3, figsize=(w/dpi, h/dpi), dpi=dpi)

ax[0].imshow(im_n.permute(1, 2, 0).clip(0, 1))
ax[0].set_title('Noisy image')
ax[1].imshow(noise.permute(1, 2, 0).clip(0, 1))
ax[1].set_title('Noise')
ax[2].imshow(im.permute(1, 2, 0).clip(0, 1))
ax[2].set_title('Actual image')
plt.show()
# Out:
# Forward diffusion step at stage t = 157.

# %% [markdown]
# ## Plot the variance schedule and $\bar{\alpha}$

# %%
from utils.diffusionDataset import get_alpha_bar

T = 1000
t = np.arange(T+1)
s = 1e-3

alpha_bar = get_alpha_bar(variance_schedule)

w, h, dpi = 1000, 500, 100
fig, ax1 = plt.subplots(figsize=(w/dpi, h/dpi), dpi=dpi)
ax2 = ax1.twinx()

ax1.set_xlabel('t/T')

color = 'C1'
ax1.plot(alpha_bar, color=color)
ax1.set_ylabel(r'$\bar{\alpha}_t$', color=color)
ax2.spines['left'].set_color(color)
ax1.tick_params(axis='y', colors=color)

color = 'C0'
ax2.plot(variance_schedule, color=color)
ax2.set_ylabel(r'$\beta_t$', color=color)
ax2.spines['right'].set_color(color)
ax2.tick_params(axis='y', colors=color)

plt.show()

# %% [markdown]
# # Train Model

# %%
f'{type(net)}'.split('.')[-1][:-2]
# Out:
# 'Unet'

# %%
(im_n, t), noise = next(iter(data_loader_train))
#im_n = im_n[0]
#t = t.numpy()[0]
#noise = noise[0]

"""noise_pred = net.forward(im_n, t)
noise_pred.shape"""
# Out:
# 'noise_pred = net.forward(im_n, t)\nnoise_pred.shape'

# %%
from models.fourthModel import FourthModel
from torchsummary import summary

net = FourthModel(dim=128)

summary(net, input_data=(im_n, t))
# Out:
# torch.Size([16, 3, 128, 128])
# torch.Size([16])
# torch.Size([16, 512])
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Conv2d: 1-1                                 [-1, 84, 128, 128]        12,432
# ├─Sequential: 1-2                             [-1, 512]                 --
# |    └─SinusoidalPositionEmbeddings: 2-1      [-1, 128]                 --
# |    └─Linear: 2-2                            [-1, 512]                 66,048
# |    └─GELU: 2-3                              [-1, 512]                 --
# |    └─Linear: 2-4                            [-1, 512]                 262,656
# ├─ModuleList: 1                               []                        --
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-1                [-1, 128, 128, 128]       547,684
# |    |    └─ConvNextBlock: 3-2                [-1, 128, 128, 128]       663,040
# |    |    └─Residual: 3-3                     [-1, 128, 128, 128]       66,176
# |    |    └─Conv2d: 3-4                       [-1, 128, 64, 64]         262,272
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-5                [-1, 256, 64, 64]         1,876,608
# |    |    └─ConvNextBlock: 3-6                [-1, 256, 64, 64]         2,505,728
# |    |    └─Residual: 3-7                     [-1, 256, 64, 64]         132,352
# |    |    └─Conv2d: 3-8                       [-1, 256, 32, 32]         1,048,832
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-9                [-1, 512, 32, 32]         7,357,696
# |    |    └─ConvNextBlock: 3-10               [-1, 512, 32, 32]         9,730,048
# |    |    └─Residual: 3-11                    [-1, 512, 32, 32]         264,704
# |    |    └─Conv2d: 3-12                      [-1, 512, 16, 16]         4,194,816
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-13               [-1, 1024, 16, 16]        29,133,312
# |    |    └─ConvNextBlock: 3-14               [-1, 1024, 16, 16]        38,334,464
# |    |    └─Residual: 3-15                    [-1, 1024, 16, 16]        529,408
# |    |    └─Identity: 3-16                    [-1, 1024, 16, 16]        --
# ├─ConvNextBlock: 1-3                          [-1, 1024, 16, 16]        --
# |    └─Conv2d: 2-5                            [-1, 1024, 16, 16]        51,200
# |    └─Sequential: 2-6                        [-1, 1024]                --
# |    |    └─GELU: 3-17                        [-1, 512]                 --
# |    |    └─Linear: 3-18                      [-1, 1024]                525,312
# |    └─Sequential: 2-7                        [-1, 1024, 16, 16]        --
# |    |    └─GroupNorm: 3-19                   [-1, 1024, 16, 16]        2,048
# |    |    └─Conv2d: 3-20                      [-1, 2048, 16, 16]        18,876,416
# |    |    └─GELU: 3-21                        [-1, 2048, 16, 16]        --
# |    |    └─GroupNorm: 3-22                   [-1, 2048, 16, 16]        4,096
# |    |    └─Conv2d: 3-23                      [-1, 1024, 16, 16]        18,875,392
# |    └─Identity: 2-8                          [-1, 1024, 16, 16]        --
# ├─Residual: 1-4                               [-1, 1024, 16, 16]        --
# |    └─PreNorm: 2-9                           [-1, 1024, 16, 16]        --
# |    |    └─GroupNorm: 3-24                   [-1, 1024, 16, 16]        2,048
# |    |    └─Attention: 3-25                   [-1, 1024, 16, 16]        525,312
# ├─ConvNextBlock: 1-5                          [-1, 1024, 16, 16]        --
# |    └─Conv2d: 2-10                           [-1, 1024, 16, 16]        51,200
# |    └─Sequential: 2-11                       [-1, 1024]                --
# |    |    └─GELU: 3-26                        [-1, 512]                 --
# |    |    └─Linear: 3-27                      [-1, 1024]                525,312
# |    └─Sequential: 2-12                       [-1, 1024, 16, 16]        --
# |    |    └─GroupNorm: 3-28                   [-1, 1024, 16, 16]        2,048
# |    |    └─Conv2d: 3-29                      [-1, 2048, 16, 16]        18,876,416
# |    |    └─GELU: 3-30                        [-1, 2048, 16, 16]        --
# |    |    └─GroupNorm: 3-31                   [-1, 2048, 16, 16]        4,096
# |    |    └─Conv2d: 3-32                      [-1, 1024, 16, 16]        18,875,392
# |    └─Identity: 2-13                         [-1, 1024, 16, 16]        --
# ├─ModuleList: 1                               []                        --
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-33               [-1, 512, 16, 16]         25,802,752
# |    |    └─ConvNextBlock: 3-34               [-1, 512, 16, 16]         9,730,048
# |    |    └─Residual: 3-35                    [-1, 512, 16, 16]         264,704
# |    |    └─ConvTranspose2d: 3-36             [-1, 512, 32, 32]         4,194,816
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-37               [-1, 256, 32, 32]         6,740,992
# |    |    └─ConvNextBlock: 3-38               [-1, 256, 32, 32]         2,505,728
# |    |    └─Residual: 3-39                    [-1, 256, 32, 32]         132,352
# |    |    └─ConvTranspose2d: 3-40             [-1, 256, 64, 64]         1,048,832
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-41               [-1, 128, 64, 64]         1,830,400
# |    |    └─ConvNextBlock: 3-42               [-1, 128, 64, 64]         663,040
# |    |    └─Residual: 3-43                    [-1, 128, 64, 64]         66,176
# |    |    └─ConvTranspose2d: 3-44             [-1, 128, 128, 128]       262,272
# ├─Sequential: 1-6                             [-1, 3, 128, 128]         --
# |    └─ConvNextBlock: 2-14                    [-1, 128, 128, 128]       --
# |    |    └─Conv2d: 3-45                      [-1, 128, 128, 128]       6,400
# |    |    └─Sequential: 3-46                  [-1, 128, 128, 128]       590,976
# |    |    └─Identity: 3-47                    [-1, 128, 128, 128]       --
# |    └─Conv2d: 2-15                           [-1, 3, 128, 128]         387
# ===============================================================================================
# Total params: 228,024,439
# Trainable params: 228,024,439
# Non-trainable params: 0
# Total mult-adds (G): 47.92
# ===============================================================================================
# Input size (MB): 3.00
# Forward/backward pass size (MB): 310.15
# Params size (MB): 869.84
# Estimated Total Size (MB): 1182.99
# ===============================================================================================
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Conv2d: 1-1                                 [-1, 84, 128, 128]        12,432
# ├─Sequential: 1-2                             [-1, 512]                 --
# |    └─SinusoidalPositionEmbeddings: 2-1      [-1, 128]                 --
# |    └─Linear: 2-2                            [-1, 512]                 66,048
# |    └─GELU: 2-3                              [-1, 512]                 --
# |    └─Linear: 2-4                            [-1, 512]                 262,656
# ├─ModuleList: 1                               []                        --
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-1                [-1, 128, 128, 128]       547,684
# |    |    └─ConvNextBlock: 3-2                [-1, 128, 128, 128]       663,040
# |    |    └─Residual: 3-3                     [-1, 128, 128, 128]       66,176
# |    |    └─Conv2d: 3-4                       [-1, 128, 64, 64]         262,272
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-5                [-1, 256, 64, 64]         1,876,608
# |    |    └─ConvNextBlock: 3-6                [-1, 256, 64, 64]         2,505,728
# |    |    └─Residual: 3-7                     [-1, 256, 64, 64]         132,352
# |    |    └─Conv2d: 3-8                       [-1, 256, 32, 32]         1,048,832
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-9                [-1, 512, 32, 32]         7,357,696
# |    |    └─ConvNextBlock: 3-10               [-1, 512, 32, 32]         9,730,048
# |    |    └─Residual: 3-11                    [-1, 512, 32, 32]         264,704
# |    |    └─Conv2d: 3-12                      [-1, 512, 16, 16]         4,194,816
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-13               [-1, 1024, 16, 16]        29,133,312
# |    |    └─ConvNextBlock: 3-14               [-1, 1024, 16, 16]        38,334,464
# |    |    └─Residual: 3-15                    [-1, 1024, 16, 16]        529,408
# |    |    └─Identity: 3-16                    [-1, 1024, 16, 16]        --
# ├─ConvNextBlock: 1-3                          [-1, 1024, 16, 16]        --
# |    └─Conv2d: 2-5                            [-1, 1024, 16, 16]        51,200
# |    └─Sequential: 2-6                        [-1, 1024]                --
# |    |    └─GELU: 3-17                        [-1, 512]                 --
# |    |    └─Linear: 3-18                      [-1, 1024]                525,312
# |    └─Sequential: 2-7                        [-1, 1024, 16, 16]        --
# |    |    └─GroupNorm: 3-19                   [-1, 1024, 16, 16]        2,048
# |    |    └─Conv2d: 3-20                      [-1, 2048, 16, 16]        18,876,416
# |    |    └─GELU: 3-21                        [-1, 2048, 16, 16]        --
# |    |    └─GroupNorm: 3-22                   [-1, 2048, 16, 16]        4,096
# |    |    └─Conv2d: 3-23                      [-1, 1024, 16, 16]        18,875,392
# |    └─Identity: 2-8                          [-1, 1024, 16, 16]        --
# ├─Residual: 1-4                               [-1, 1024, 16, 16]        --
# |    └─PreNorm: 2-9                           [-1, 1024, 16, 16]        --
# |    |    └─GroupNorm: 3-24                   [-1, 1024, 16, 16]        2,048
# |    |    └─Attention: 3-25                   [-1, 1024, 16, 16]        525,312
# ├─ConvNextBlock: 1-5                          [-1, 1024, 16, 16]        --
# |    └─Conv2d: 2-10                           [-1, 1024, 16, 16]        51,200
# |    └─Sequential: 2-11                       [-1, 1024]                --
# |    |    └─GELU: 3-26                        [-1, 512]                 --
# |    |    └─Linear: 3-27                      [-1, 1024]                525,312
# |    └─Sequential: 2-12                       [-1, 1024, 16, 16]        --
# |    |    └─GroupNorm: 3-28                   [-1, 1024, 16, 16]        2,048
# |    |    └─Conv2d: 3-29                      [-1, 2048, 16, 16]        18,876,416
# |    |    └─GELU: 3-30                        [-1, 2048, 16, 16]        --
# |    |    └─GroupNorm: 3-31                   [-1, 2048, 16, 16]        4,096
# |    |    └─Conv2d: 3-32                      [-1, 1024, 16, 16]        18,875,392
# |    └─Identity: 2-13                         [-1, 1024, 16, 16]        --
# ├─ModuleList: 1                               []                        --
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-33               [-1, 512, 16, 16]         25,802,752
# |    |    └─ConvNextBlock: 3-34               [-1, 512, 16, 16]         9,730,048
# |    |    └─Residual: 3-35                    [-1, 512, 16, 16]         264,704
# |    |    └─ConvTranspose2d: 3-36             [-1, 512, 32, 32]         4,194,816
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-37               [-1, 256, 32, 32]         6,740,992
# |    |    └─ConvNextBlock: 3-38               [-1, 256, 32, 32]         2,505,728
# |    |    └─Residual: 3-39                    [-1, 256, 32, 32]         132,352
# |    |    └─ConvTranspose2d: 3-40             [-1, 256, 64, 64]         1,048,832
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-41               [-1, 128, 64, 64]         1,830,400
# |    |    └─ConvNextBlock: 3-42               [-1, 128, 64, 64]         663,040
# |    |    └─Residual: 3-43                    [-1, 128, 64, 64]         66,176
# |    |    └─ConvTranspose2d: 3-44             [-1, 128, 128, 128]       262,272
# ├─Sequential: 1-6                             [-1, 3, 128, 128]         --
# |    └─ConvNextBlock: 2-14                    [-1, 128, 128, 128]       --
# |    |    └─Conv2d: 3-45                      [-1, 128, 128, 128]       6,400
# |    |    └─Sequential: 3-46                  [-1, 128, 128, 128]       590,976
# |    |    └─Identity: 3-47                    [-1, 128, 128, 128]       --
# |    └─Conv2d: 2-15                           [-1, 3, 128, 128]         387
# ===============================================================================================
# Total params: 228,024,439
# Trainable params: 228,024,439
# Non-trainable params: 0
# Total mult-adds (G): 47.92
# ===============================================================================================
# Input size (MB): 3.00
# Forward/backward pass size (MB): 310.15
# Params size (MB): 869.84
# Estimated Total Size (MB): 1182.99
# ===============================================================================================

# %%
from models.fourthModel import FourthModel
from torchsummary import summary

net = FourthModel(dim=128, use_convnext=False, dim_mults=(1,2,4))

summary(net, input_data=(im_n, t))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Conv2d: 1-1                                 [-1, 84, 128, 128]        12,432
# ├─Sequential: 1-2                             [-1, 512]                 --
# |    └─SinusoidalPositionEmbeddings: 2-1      [-1, 128]                 --
# |    └─Linear: 2-2                            [-1, 512]                 66,048
# |    └─GELU: 2-3                              [-1, 512]                 --
# |    └─Linear: 2-4                            [-1, 512]                 262,656
# ├─ModuleList: 1                               []                        --
# |    └─ModuleList: 2                          []                        --
# |    |    └─ResnetBlock: 3-1                  [-1, 128, 128, 128]       321,536
# |    |    └─ResnetBlock: 3-2                  [-1, 128, 128, 128]       361,344
# |    |    └─Residual: 3-3                     [-1, 128, 128, 128]       66,176
# |    |    └─Conv2d: 3-4                       [-1, 128, 64, 64]         262,272
# |    └─ModuleList: 2                          []                        --
# |    |    └─ResnetBlock: 3-5                  [-1, 256, 64, 64]         1,050,624
# |    |    └─ResnetBlock: 3-6                  [-1, 256, 64, 64]         1,312,512
# |    |    └─Residual: 3-7                     [-1, 256, 64, 64]         132,352
# |    |    └─Conv2d: 3-8                       [-1, 256, 32, 32]         1,048,832
# |    └─ModuleList: 2                          []                        --
# |    |    └─ResnetBlock: 3-9                  [-1, 512, 32, 32]         3,936,256
# |    |    └─ResnetBlock: 3-10                 [-1, 512, 32, 32]         4,984,320
# |    |    └─Residual: 3-11                    [-1, 512, 32, 32]         264,704
# |    |    └─Identity: 3-12                    [-1, 512, 32, 32]         --
# ├─ResnetBlock: 1-3                            [-1, 512, 32, 32]         --
# |    └─Block: 2-5                             [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-13                      [-1, 512, 32, 32]         2,359,808
# |    |    └─GroupNorm: 3-14                   [-1, 512, 32, 32]         1,024
# |    |    └─SiLU: 3-15                        [-1, 512, 32, 32]         --
# |    └─Sequential: 2-6                        [-1, 512]                 --
# |    |    └─SiLU: 3-16                        [-1, 512]                 --
# |    |    └─Linear: 3-17                      [-1, 512]                 262,656
# |    └─Block: 2-7                             [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-18                      [-1, 512, 32, 32]         2,359,808
# |    |    └─GroupNorm: 3-19                   [-1, 512, 32, 32]         1,024
# |    |    └─SiLU: 3-20                        [-1, 512, 32, 32]         --
# |    └─Identity: 2-8                          [-1, 512, 32, 32]         --
# ├─Residual: 1-4                               [-1, 512, 32, 32]         --
# |    └─PreNorm: 2-9                           [-1, 512, 32, 32]         --
# |    |    └─GroupNorm: 3-21                   [-1, 512, 32, 32]         1,024
# |    |    └─Attention: 3-22                   [-1, 512, 32, 32]         262,656
# ├─ResnetBlock: 1-5                            [-1, 512, 32, 32]         --
# |    └─Block: 2-10                            [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-23                      [-1, 512, 32, 32]         2,359,808
# |    |    └─GroupNorm: 3-24                   [-1, 512, 32, 32]         1,024
# |    |    └─SiLU: 3-25                        [-1, 512, 32, 32]         --
# |    └─Sequential: 2-11                       [-1, 512]                 --
# |    |    └─SiLU: 3-26                        [-1, 512]                 --
# |    |    └─Linear: 3-27                      [-1, 512]                 262,656
# |    └─Block: 2-12                            [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-28                      [-1, 512, 32, 32]         2,359,808
# |    |    └─GroupNorm: 3-29                   [-1, 512, 32, 32]         1,024
# |    |    └─SiLU: 3-30                        [-1, 512, 32, 32]         --
# |    └─Identity: 2-13                         [-1, 512, 32, 32]         --
# ├─ModuleList: 1                               []                        --
# |    └─ModuleList: 2                          []                        --
# |    |    └─ResnetBlock: 3-31                 [-1, 256, 32, 32]         3,344,384
# |    |    └─ResnetBlock: 3-32                 [-1, 256, 32, 32]         1,312,512
# |    |    └─Residual: 3-33                    [-1, 256, 32, 32]         132,352
# |    |    └─ConvTranspose2d: 3-34             [-1, 256, 64, 64]         1,048,832
# |    └─ModuleList: 2                          []                        --
# |    |    └─ResnetBlock: 3-35                 [-1, 128, 64, 64]         869,376
# |    |    └─ResnetBlock: 3-36                 [-1, 128, 64, 64]         361,344
# |    |    └─Residual: 3-37                    [-1, 128, 64, 64]         66,176
# |    |    └─ConvTranspose2d: 3-38             [-1, 128, 128, 128]       262,272
# ├─Sequential: 1-6                             [-1, 3, 128, 128]         --
# |    └─ResnetBlock: 2-14                      [-1, 128, 128, 128]       --
# |    |    └─Block: 3-39                       [-1, 128, 128, 128]       147,840
# |    |    └─Block: 3-40                       [-1, 128, 128, 128]       147,840
# |    |    └─Identity: 3-41                    [-1, 128, 128, 128]       --
# |    └─Conv2d: 2-15                           [-1, 3, 128, 128]         387
# ===============================================================================================
# Total params: 32,007,699
# Trainable params: 32,007,699
# Non-trainable params: 0
# Total mult-adds (G): 26.75
# ===============================================================================================
# Input size (MB): 3.00
# Forward/backward pass size (MB): 181.89
# Params size (MB): 122.10
# Estimated Total Size (MB): 306.99
# ===============================================================================================
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Conv2d: 1-1                                 [-1, 84, 128, 128]        12,432
# ├─Sequential: 1-2                             [-1, 512]                 --
# |    └─SinusoidalPositionEmbeddings: 2-1      [-1, 128]                 --
# |    └─Linear: 2-2                            [-1, 512]                 66,048
# |    └─GELU: 2-3                              [-1, 512]                 --
# |    └─Linear: 2-4                            [-1, 512]                 262,656
# ├─ModuleList: 1                               []                        --
# |    └─ModuleList: 2                          []                        --
# |    |    └─ResnetBlock: 3-1                  [-1, 128, 128, 128]       321,536
# |    |    └─ResnetBlock: 3-2                  [-1, 128, 128, 128]       361,344
# |    |    └─Residual: 3-3                     [-1, 128, 128, 128]       66,176
# |    |    └─Conv2d: 3-4                       [-1, 128, 64, 64]         262,272
# |    └─ModuleList: 2                          []                        --
# |    |    └─ResnetBlock: 3-5                  [-1, 256, 64, 64]         1,050,624
# |    |    └─ResnetBlock: 3-6                  [-1, 256, 64, 64]         1,312,512
# |    |    └─Residual: 3-7                     [-1, 256, 64, 64]         132,352
# |    |    └─Conv2d: 3-8                       [-1, 256, 32, 32]         1,048,832
# |    └─ModuleList: 2                          []                        --
# |    |    └─ResnetBlock: 3-9                  [-1, 512, 32, 32]         3,936,256
# |    |    └─ResnetBlock: 3-10                 [-1, 512, 32, 32]         4,984,320
# |    |    └─Residual: 3-11                    [-1, 512, 32, 32]         264,704
# |    |    └─Identity: 3-12                    [-1, 512, 32, 32]         --
# ├─ResnetBlock: 1-3                            [-1, 512, 32, 32]         --
# |    └─Block: 2-5                             [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-13                      [-1, 512, 32, 32]         2,359,808
# |    |    └─GroupNorm: 3-14                   [-1, 512, 32, 32]         1,024
# |    |    └─SiLU: 3-15                        [-1, 512, 32, 32]         --
# |    └─Sequential: 2-6                        [-1, 512]                 --
# |    |    └─SiLU: 3-16                        [-1, 512]                 --
# |    |    └─Linear: 3-17                      [-1, 512]                 262,656
# |    └─Block: 2-7                             [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-18                      [-1, 512, 32, 32]         2,359,808
# |    |    └─GroupNorm: 3-19                   [-1, 512, 32, 32]         1,024
# |    |    └─SiLU: 3-20                        [-1, 512, 32, 32]         --
# |    └─Identity: 2-8                          [-1, 512, 32, 32]         --
# ├─Residual: 1-4                               [-1, 512, 32, 32]         --
# |    └─PreNorm: 2-9                           [-1, 512, 32, 32]         --
# |    |    └─GroupNorm: 3-21                   [-1, 512, 32, 32]         1,024
# |    |    └─Attention: 3-22                   [-1, 512, 32, 32]         262,656
# ├─ResnetBlock: 1-5                            [-1, 512, 32, 32]         --
# |    └─Block: 2-10                            [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-23                      [-1, 512, 32, 32]         2,359,808
# |    |    └─GroupNorm: 3-24                   [-1, 512, 32, 32]         1,024
# |    |    └─SiLU: 3-25                        [-1, 512, 32, 32]         --
# |    └─Sequential: 2-11                       [-1, 512]                 --
# |    |    └─SiLU: 3-26                        [-1, 512]                 --
# |    |    └─Linear: 3-27                      [-1, 512]                 262,656
# |    └─Block: 2-12                            [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-28                      [-1, 512, 32, 32]         2,359,808
# |    |    └─GroupNorm: 3-29                   [-1, 512, 32, 32]         1,024
# |    |    └─SiLU: 3-30                        [-1, 512, 32, 32]         --
# |    └─Identity: 2-13                         [-1, 512, 32, 32]         --
# ├─ModuleList: 1                               []                        --
# |    └─ModuleList: 2                          []                        --
# |    |    └─ResnetBlock: 3-31                 [-1, 256, 32, 32]         3,344,384
# |    |    └─ResnetBlock: 3-32                 [-1, 256, 32, 32]         1,312,512
# |    |    └─Residual: 3-33                    [-1, 256, 32, 32]         132,352
# |    |    └─ConvTranspose2d: 3-34             [-1, 256, 64, 64]         1,048,832
# |    └─ModuleList: 2                          []                        --
# |    |    └─ResnetBlock: 3-35                 [-1, 128, 64, 64]         869,376
# |    |    └─ResnetBlock: 3-36                 [-1, 128, 64, 64]         361,344
# |    |    └─Residual: 3-37                    [-1, 128, 64, 64]         66,176
# |    |    └─ConvTranspose2d: 3-38             [-1, 128, 128, 128]       262,272
# ├─Sequential: 1-6                             [-1, 3, 128, 128]         --
# |    └─ResnetBlock: 2-14                      [-1, 128, 128, 128]       --
# |    |    └─Block: 3-39                       [-1, 128, 128, 128]       147,840
# |    |    └─Block: 3-40                       [-1, 128, 128, 128]       147,840
# |    |    └─Identity: 3-41                    [-1, 128, 128, 128]       --
# |    └─Conv2d: 2-15                           [-1, 3, 128, 128]         387
# ===============================================================================================
# Total params: 32,007,699
# Trainable params: 32,007,699
# Non-trainable params: 0
# Total mult-adds (G): 26.75
# ===============================================================================================
# Input size (MB): 3.00
# Forward/backward pass size (MB): 181.89
# Params size (MB): 122.10
# Estimated Total Size (MB): 306.99
# ===============================================================================================

# %%
from models.fourthModel import FourthModel
from torchsummary import summary

net = FourthModel(dim=128, use_convnext=True, dim_mults=(1,2,4))

summary(net, input_data=(im_n, t))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Conv2d: 1-1                                 [-1, 84, 128, 128]        12,432
# ├─Sequential: 1-2                             [-1, 512]                 --
# |    └─SinusoidalPositionEmbeddings: 2-1      [-1, 128]                 --
# |    └─Linear: 2-2                            [-1, 512]                 66,048
# |    └─GELU: 2-3                              [-1, 512]                 --
# |    └─Linear: 2-4                            [-1, 512]                 262,656
# ├─ModuleList: 1                               []                        --
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-1                [-1, 128, 128, 128]       547,684
# |    |    └─ConvNextBlock: 3-2                [-1, 128, 128, 128]       663,040
# |    |    └─Residual: 3-3                     [-1, 128, 128, 128]       66,176
# |    |    └─Conv2d: 3-4                       [-1, 128, 64, 64]         262,272
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-5                [-1, 256, 64, 64]         1,876,608
# |    |    └─ConvNextBlock: 3-6                [-1, 256, 64, 64]         2,505,728
# |    |    └─Residual: 3-7                     [-1, 256, 64, 64]         132,352
# |    |    └─Conv2d: 3-8                       [-1, 256, 32, 32]         1,048,832
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-9                [-1, 512, 32, 32]         7,357,696
# |    |    └─ConvNextBlock: 3-10               [-1, 512, 32, 32]         9,730,048
# |    |    └─Residual: 3-11                    [-1, 512, 32, 32]         264,704
# |    |    └─Identity: 3-12                    [-1, 512, 32, 32]         --
# ├─ConvNextBlock: 1-3                          [-1, 512, 32, 32]         --
# |    └─Conv2d: 2-5                            [-1, 512, 32, 32]         25,600
# |    └─Sequential: 2-6                        [-1, 512]                 --
# |    |    └─GELU: 3-13                        [-1, 512]                 --
# |    |    └─Linear: 3-14                      [-1, 512]                 262,656
# |    └─Sequential: 2-7                        [-1, 512, 32, 32]         --
# |    |    └─GroupNorm: 3-15                   [-1, 512, 32, 32]         1,024
# |    |    └─Conv2d: 3-16                      [-1, 1024, 32, 32]        4,719,616
# |    |    └─GELU: 3-17                        [-1, 1024, 32, 32]        --
# |    |    └─GroupNorm: 3-18                   [-1, 1024, 32, 32]        2,048
# |    |    └─Conv2d: 3-19                      [-1, 512, 32, 32]         4,719,104
# |    └─Identity: 2-8                          [-1, 512, 32, 32]         --
# ├─Residual: 1-4                               [-1, 512, 32, 32]         --
# |    └─PreNorm: 2-9                           [-1, 512, 32, 32]         --
# |    |    └─GroupNorm: 3-20                   [-1, 512, 32, 32]         1,024
# |    |    └─Attention: 3-21                   [-1, 512, 32, 32]         262,656
# ├─ConvNextBlock: 1-5                          [-1, 512, 32, 32]         --
# |    └─Conv2d: 2-10                           [-1, 512, 32, 32]         25,600
# |    └─Sequential: 2-11                       [-1, 512]                 --
# |    |    └─GELU: 3-22                        [-1, 512]                 --
# |    |    └─Linear: 3-23                      [-1, 512]                 262,656
# |    └─Sequential: 2-12                       [-1, 512, 32, 32]         --
# |    |    └─GroupNorm: 3-24                   [-1, 512, 32, 32]         1,024
# |    |    └─Conv2d: 3-25                      [-1, 1024, 32, 32]        4,719,616
# |    |    └─GELU: 3-26                        [-1, 1024, 32, 32]        --
# |    |    └─GroupNorm: 3-27                   [-1, 1024, 32, 32]        2,048
# |    |    └─Conv2d: 3-28                      [-1, 512, 32, 32]         4,719,104
# |    └─Identity: 2-13                         [-1, 512, 32, 32]         --
# ├─ModuleList: 1                               []                        --
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-29               [-1, 256, 32, 32]         6,740,992
# |    |    └─ConvNextBlock: 3-30               [-1, 256, 32, 32]         2,505,728
# |    |    └─Residual: 3-31                    [-1, 256, 32, 32]         132,352
# |    |    └─ConvTranspose2d: 3-32             [-1, 256, 64, 64]         1,048,832
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-33               [-1, 128, 64, 64]         1,830,400
# |    |    └─ConvNextBlock: 3-34               [-1, 128, 64, 64]         663,040
# |    |    └─Residual: 3-35                    [-1, 128, 64, 64]         66,176
# |    |    └─ConvTranspose2d: 3-36             [-1, 128, 128, 128]       262,272
# ├─Sequential: 1-6                             [-1, 3, 128, 128]         --
# |    └─ConvNextBlock: 2-14                    [-1, 128, 128, 128]       --
# |    |    └─Conv2d: 3-37                      [-1, 128, 128, 128]       6,400
# |    |    └─Sequential: 3-38                  [-1, 128, 128, 128]       590,976
# |    |    └─Identity: 3-39                    [-1, 128, 128, 128]       --
# |    └─Conv2d: 2-15                           [-1, 3, 128, 128]         387
# ===============================================================================================
# Total params: 58,367,607
# Trainable params: 58,367,607
# Non-trainable params: 0
# Total mult-adds (G): 41.93
# ===============================================================================================
# Input size (MB): 3.00
# Forward/backward pass size (MB): 328.39
# Params size (MB): 222.65
# Estimated Total Size (MB): 554.05
# ===============================================================================================
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Conv2d: 1-1                                 [-1, 84, 128, 128]        12,432
# ├─Sequential: 1-2                             [-1, 512]                 --
# |    └─SinusoidalPositionEmbeddings: 2-1      [-1, 128]                 --
# |    └─Linear: 2-2                            [-1, 512]                 66,048
# |    └─GELU: 2-3                              [-1, 512]                 --
# |    └─Linear: 2-4                            [-1, 512]                 262,656
# ├─ModuleList: 1                               []                        --
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-1                [-1, 128, 128, 128]       547,684
# |    |    └─ConvNextBlock: 3-2                [-1, 128, 128, 128]       663,040
# |    |    └─Residual: 3-3                     [-1, 128, 128, 128]       66,176
# |    |    └─Conv2d: 3-4                       [-1, 128, 64, 64]         262,272
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-5                [-1, 256, 64, 64]         1,876,608
# |    |    └─ConvNextBlock: 3-6                [-1, 256, 64, 64]         2,505,728
# |    |    └─Residual: 3-7                     [-1, 256, 64, 64]         132,352
# |    |    └─Conv2d: 3-8                       [-1, 256, 32, 32]         1,048,832
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-9                [-1, 512, 32, 32]         7,357,696
# |    |    └─ConvNextBlock: 3-10               [-1, 512, 32, 32]         9,730,048
# |    |    └─Residual: 3-11                    [-1, 512, 32, 32]         264,704
# |    |    └─Identity: 3-12                    [-1, 512, 32, 32]         --
# ├─ConvNextBlock: 1-3                          [-1, 512, 32, 32]         --
# |    └─Conv2d: 2-5                            [-1, 512, 32, 32]         25,600
# |    └─Sequential: 2-6                        [-1, 512]                 --
# |    |    └─GELU: 3-13                        [-1, 512]                 --
# |    |    └─Linear: 3-14                      [-1, 512]                 262,656
# |    └─Sequential: 2-7                        [-1, 512, 32, 32]         --
# |    |    └─GroupNorm: 3-15                   [-1, 512, 32, 32]         1,024
# |    |    └─Conv2d: 3-16                      [-1, 1024, 32, 32]        4,719,616
# |    |    └─GELU: 3-17                        [-1, 1024, 32, 32]        --
# |    |    └─GroupNorm: 3-18                   [-1, 1024, 32, 32]        2,048
# |    |    └─Conv2d: 3-19                      [-1, 512, 32, 32]         4,719,104
# |    └─Identity: 2-8                          [-1, 512, 32, 32]         --
# ├─Residual: 1-4                               [-1, 512, 32, 32]         --
# |    └─PreNorm: 2-9                           [-1, 512, 32, 32]         --
# |    |    └─GroupNorm: 3-20                   [-1, 512, 32, 32]         1,024
# |    |    └─Attention: 3-21                   [-1, 512, 32, 32]         262,656
# ├─ConvNextBlock: 1-5                          [-1, 512, 32, 32]         --
# |    └─Conv2d: 2-10                           [-1, 512, 32, 32]         25,600
# |    └─Sequential: 2-11                       [-1, 512]                 --
# |    |    └─GELU: 3-22                        [-1, 512]                 --
# |    |    └─Linear: 3-23                      [-1, 512]                 262,656
# |    └─Sequential: 2-12                       [-1, 512, 32, 32]         --
# |    |    └─GroupNorm: 3-24                   [-1, 512, 32, 32]         1,024
# |    |    └─Conv2d: 3-25                      [-1, 1024, 32, 32]        4,719,616
# |    |    └─GELU: 3-26                        [-1, 1024, 32, 32]        --
# |    |    └─GroupNorm: 3-27                   [-1, 1024, 32, 32]        2,048
# |    |    └─Conv2d: 3-28                      [-1, 512, 32, 32]         4,719,104
# |    └─Identity: 2-13                         [-1, 512, 32, 32]         --
# ├─ModuleList: 1                               []                        --
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-29               [-1, 256, 32, 32]         6,740,992
# |    |    └─ConvNextBlock: 3-30               [-1, 256, 32, 32]         2,505,728
# |    |    └─Residual: 3-31                    [-1, 256, 32, 32]         132,352
# |    |    └─ConvTranspose2d: 3-32             [-1, 256, 64, 64]         1,048,832
# |    └─ModuleList: 2                          []                        --
# |    |    └─ConvNextBlock: 3-33               [-1, 128, 64, 64]         1,830,400
# |    |    └─ConvNextBlock: 3-34               [-1, 128, 64, 64]         663,040
# |    |    └─Residual: 3-35                    [-1, 128, 64, 64]         66,176
# |    |    └─ConvTranspose2d: 3-36             [-1, 128, 128, 128]       262,272
# ├─Sequential: 1-6                             [-1, 3, 128, 128]         --
# |    └─ConvNextBlock: 2-14                    [-1, 128, 128, 128]       --
# |    |    └─Conv2d: 3-37                      [-1, 128, 128, 128]       6,400
# |    |    └─Sequential: 3-38                  [-1, 128, 128, 128]       590,976
# |    |    └─Identity: 3-39                    [-1, 128, 128, 128]       --
# |    └─Conv2d: 2-15                           [-1, 3, 128, 128]         387
# ===============================================================================================
# Total params: 58,367,607
# Trainable params: 58,367,607
# Non-trainable params: 0
# Total mult-adds (G): 41.93
# ===============================================================================================
# Input size (MB): 3.00
# Forward/backward pass size (MB): 328.39
# Params size (MB): 222.65
# Estimated Total Size (MB): 554.05
# ===============================================================================================

# %%
# Out:
# 'noise_pred = net.forward(im_n, t)\nnoise_pred.shape'

# %%
from models.firstModel import FirstModel
from models.secondModel import *
from models.fourthModel import Unet
from utils.training import train_model

net = SecondModelConcatFC(img_shape=(3,)+image_size, device=device)

epochs = 30
additional_info = {'batch_size': batch_size,
                   'image_size': image_size,
                   'variance_schedule': variance_schedule
                  }

checkpoint_dict = train_model(net=net,
                              data_loader_train=data_loader_train,
                              loss_function=torch.nn.MSELoss(),
                              epochs=epochs,
                              device=device,
                              checkpoint_folder='checkpoints/' + f'{type(net)}'.split('.')[-1][:-2],
                              clear_previous_checkpoints=True,
                              additional_info=additional_info)

plt.plot(checkpoint_dict['loss_history'], 'o-')
plt.yscale('log')

plt.show()

# %%
np.argmin(checkpoint_dict['loss_history'])

# %% [markdown]
# # Test Performance

# %% [markdown]
# Get an image from the dataset

# %%
image_size_test = (512, 512)
batch_size_test = 1

dataset_test = DiffusionDataset(data=dataset_flowers,
                                variance_schedule=variance_schedule,
                                transform=Compose([ToTensor(),
                                                   RandomResizedCrop(image_size_test)]))

data_loader_test = DataLoader(dataset_test,
                              batch_size=batch_size,
                              pin_memory=True,
                              shuffle=True)

# %%
from utils.reconstruction import reconstruct_image_from_noise
from utils.eval import visualize_single_reconstruction

(noisy_image_batch, t_batch), noise_batch = next(iter(data_loader_test))
i = np.argmin(t_batch.numpy())

noisy_image = noisy_image_batch.numpy()[i]
t = t_batch.numpy()[i]
noise = noise_batch.numpy()[i]

# true original image
original_image = reconstruct_image_from_noise(noisy_image=noisy_image,
                                              noise=noise,
                                              t=t,
                                              variance_schedule=variance_schedule)

orig_name = "flower"

print(f't = {t}')

# %% [markdown]
# Get a benchmark image

# %%
from matplotlib import image
from utils.diffusionDataset import get_alpha_bar
from utils.eval import visualize_single_reconstruction

original_image = np.asarray(image.imread('test_pictures/ship.jpg'), dtype=np.float32)/255
orig_name = "ship"

# original_image = np.asarray(image.imread('test_pictures/flower_1.jpg'), dtype=np.float32)/255
# orig_name = "flower_1"

#original_image = np.asarray(image.imread('test_pictures/flower_2.jpg'), dtype=np.float32)/255
#orig_name = "flower_2"

original_image = original_image.transpose(2, 0, 1)

image_size_test = original_image.shape[1:]

t = 25

a = get_alpha_bar(variance_schedule)[t]
noisy_image = np.sqrt(a)*original_image + np.sqrt(1-a)*np.random.normal(size=original_image.shape)
noisy_image = noisy_image.clip(0, 1)

# %% [markdown]
# # Model Comparisons on single images

# %% [markdown]
# ## FirstModel

# %%
from models.firstModel import FirstModel
from utils.eval import visualize_single_reconstruction, load_weights

net = FirstModel(img_shape=(3,)+image_size_test, device=device)
load_weights(net, 'checkpoints/FirstModel/checkpoint.ckpt')
net.to(device)

visualize_single_reconstruction(net, original_image, noisy_image, t, variance_schedule, device)

# %% [markdown]
# ## SecondModelSum

# %%
from models.secondModel import SecondModelSum
from utils.eval import visualize_single_reconstruction, load_weights

net = SecondModelSum(img_shape=(3,)+image_size_test, device=device)
load_weights(net, 'checkpoints/SecondModelSum/checkpoint.ckpt')
net.to(device)

visualize_single_reconstruction(net, original_image, noisy_image, t, variance_schedule, device)

# %% [markdown]
# ## SecondModelConcat

# %%
from models.secondModel import SecondModelConcat
from utils.eval import visualize_single_reconstruction, load_weights

net = SecondModelConcat(img_shape=(3,)+image_size_test, device=device)
net_name = f'{type(net)}'.split('.')[-1][:-2]

load_weights(net, f'checkpoints/{net_name}/checkpoint_0024_best.ckpt')
net.to(device)

output_folder = f'result_pictures/{net_name}_{orig_name}_{t}'
step = [1, 5]
visualize_single_reconstruction(net, original_image, noisy_image, t, variance_schedule, device, output_folder=output_folder, step=step)

# %% [markdown]
# ## SecondModelConcatK2

# %%
from models.secondModel import SecondModelConcatK2
from utils.eval import visualize_single_reconstruction, load_weights

net = SecondModelConcatK2(img_shape=(3,)+image_size_test, device=device)
net_name = f'{type(net)}'.split('.')[-1][:-2]

load_weights(net, f'checkpoints/{net_name}/checkpoint_0029_best.ckpt')
net.to(device)

output_folder = f'result_pictures/{net_name}_{orig_name}_{t}'
step = [1, 5]
visualize_single_reconstruction(net, original_image, noisy_image, t, variance_schedule, device, output_folder=output_folder, step=step)

# %% [markdown]
# ## SecondModelConcatFC

# %%
from models.secondModel import SecondModelConcatFC
from utils.eval import visualize_single_reconstruction, load_weights

net = SecondModelConcatFC(img_shape=(3,)+image_size_test, device=device)
net_name = f'{type(net)}'.split('.')[-1][:-2]

load_weights(net, f'checkpoints/{net_name}/checkpoint_0028_best.ckpt')
net.to(device)

output_folder = f'result_pictures/{net_name}_{orig_name}_{t}'
step = [1, 5]
visualize_single_reconstruction(net, original_image, noisy_image, t, variance_schedule, device, output_folder=output_folder, step=step)
